# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")
data
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
data.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
data.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
data.tail()
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False

# %%
data["IsHoliday"].value_counts()
# Out:
# IsHoliday
# False    391909
# True      29661
# Name: count, dtype: int64

# %%
isholiday = data[data["IsHoliday"] == True]
notholiday = data[data["IsHoliday"] == False]

# %%
import matplotlib.pyplot as plt

# %%
ax = plt.axes()
ax.set_facecolor("lightblue")
plt.bar(["HOLIDAY" , "NOT HOLIDAY"] , [len(isholiday) , len(notholiday)] , color=["green" , "red"])
plt.title("HOLIDAY COUNT")
plt.ylabel("DAYS")
plt.show()

# %%
ax = plt.axes()
ax.set_facecolor("lightyellow")
plt.plot(data["Weekly_Sales"] , color="red")
plt.title("WEEKLY SALES")
plt.show()

# %%
new_data = data 
new_data
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
new_data["Date"] = new_data["Date"].apply(lambda i:i.split("-")[1])
new_data
# Out:
#         Store  Dept Date  Weekly_Sales  IsHoliday
# 0           1     1   02      24924.50      False
# 1           1     1   02      46039.49       True
# 2           1     1   02      41595.55      False
# 3           1     1   02      19403.54      False
# 4           1     1   03      21827.90      False
# ...       ...   ...  ...           ...        ...
# 421565     45    98   09        508.37      False
# 421566     45    98   10        628.10      False
# 421567     45    98   10       1061.02      False
# 421568     45    98   10        760.01      False
# 421569     45    98   10       1076.80      False
#
# [421570 rows x 5 columns]

# %%
new_data["Date"] = new_data["Date"].astype(int)
new_data
# Out:
#         Store  Dept  Date  Weekly_Sales  IsHoliday
# 0           1     1     2      24924.50      False
# 1           1     1     2      46039.49       True
# 2           1     1     2      41595.55      False
# 3           1     1     2      19403.54      False
# 4           1     1     3      21827.90      False
# ...       ...   ...   ...           ...        ...
# 421565     45    98     9        508.37      False
# 421566     45    98    10        628.10      False
# 421567     45    98    10       1061.02      False
# 421568     45    98    10        760.01      False
# 421569     45    98    10       1076.80      False
#
# [421570 rows x 5 columns]

# %%
new_data[new_data["Date"]==4]
# Out:
#         Store  Dept  Date  Weekly_Sales  IsHoliday
# 8           1     1     4      57258.43      False
# 9           1     1     4      42960.91      False
# 10          1     1     4      17596.96      False
# 11          1     1     4      16145.35      False
# 12          1     1     4      16555.11      False
# ...       ...   ...   ...           ...        ...
# 421491     45    98     4        868.74      False
# 421540     45    98     4        778.70      False
# 421541     45    98     4        559.14      False
# 421542     45    98     4        605.80      False
# 421543     45    98     4        619.41      False
#
# [41332 rows x 5 columns]

# %%
new_data[new_data["Date"]==4]["Weekly_Sales"]
# Out:
# 8         57258.43
# 9         42960.91
# 10        17596.96
# 11        16145.35
# 12        16555.11
#             ...
# 421491      868.74
# 421540      778.70
# 421541      559.14
# 421542      605.80
# 421543      619.41
# Name: Weekly_Sales, Length: 41332, dtype: float64

# %%
sum(new_data[new_data["Date"]==4]["Weekly_Sales"])
# Out:
# 646859784.9700006

# %%
sum(new_data[new_data["Date"] == 2]["Weekly_Sales"])
# Out:
# 568727890.4500039

# %%
g = []
for i in range(1 , 12+1):
    s_monthly = sum(new_data[new_data["Date"] == i]["Weekly_Sales"])
    print(f"MONTH {i} : {s_monthly}")
    g.append(s_monthly)
# Out:
# MONTH 1 : 332598438.49000037
# MONTH 2 : 568727890.4500039
# MONTH 3 : 592785901.2799964
# MONTH 4 : 646859784.9700006
# MONTH 5 : 557125571.9500018
# MONTH 6 : 622629886.8400017
# MONTH 7 : 650000977.2499989
# MONTH 8 : 613090208.820002
# MONTH 9 : 578761179.2600046
# MONTH 10 : 584784787.5900054
# MONTH 11 : 413015725.0100024
# MONTH 12 : 576838635.2000024

# %%
plt.plot(g , color="orange")
plt.title("SUM OF SALES PER MONTH")
plt.show()
